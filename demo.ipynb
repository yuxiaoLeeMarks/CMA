# %%
import torch
import torch.nn
import clip
import os
import torch.utils.data
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from scipy import interpolate
from torchvision import datasets
import torchvision

# %% [markdown]
# # Test Module

# %%
def get_output(image_inputs, text_inputs, t=1.0):
    image_features = model.encode_image(image_inputs).float()
    image_features /= image_features.norm(dim=-1, keepdim=True)

    text_features = model.encode_text(text_inputs).float()
    text_features /= text_features.norm(dim=-1, keepdim=True)
    output = (image_features @ text_features.T) / t
    return output


def get_result(ID_score, OOD_score, ood_name="None"):
    id_score = ID_score
    ood_score = OOD_score

    y_true = [1] * len(id_score) + [0] * len(ood_score)
    y_scores = id_score + ood_score
    roc_auc = roc_auc_score(y_true, y_scores)
    fpr, tpr, thresh = roc_curve(y_true, y_scores, pos_label=1)
    fpr95 = float(interpolate.interp1d(tpr, fpr)(0.95))
    print(f"OOD is {ood_name}, The AUC score is:[{roc_auc}], The FPR95 score is:[{fpr95}]")


def get_ood_score(ood_data_loader, text_inputs, len_of_ID, name="none", t=1.0):
    _pre_max = []

    for i, (images, class_ids) in enumerate(ood_data_loader):
        image_inputs = images.to(device)

        with torch.no_grad():
            logits = get_output(image_inputs, text_inputs, t=t)
            probs = logits.softmax(dim=-1).cpu().numpy()

        for j in range(probs.shape[0]):
            prob = probs[j][:len_of_ID + 1]
            _pre_max.append(prob[:len_of_ID].max())

        print(f"{name} has finished {i / len(ood_data_loader) * 100:.0f}%")
    return _pre_max

# %%
def test_in_ood_datasets(ID_dataloader, classes_list, ID_name="none", Agent="a photo of things."):
        input_text = classes_list.copy()
        L = len(classes_list)
        for i in range(L):
            input_text.append(Agent)

        text_inputs = clip.tokenize(input_text).to(device)
        print(f"text input shape {text_inputs.shape}")

        ID_pre_max = []

        for i, (images, class_ids) in enumerate(ID_dataloader):
            image_inputs = images.to(device)

            with torch.no_grad():
                logits = get_output(image_inputs, text_inputs)
                probs = logits.softmax(dim=-1).cpu().numpy()

            for j in range(probs.shape[0]):
                prob = probs[j][:L + 1]
                ID_pre_max.append(prob[:L].max())

            print(f"ID test dataset has finished {i / len(ID_dataloader) * 100:.2f}%")

        int_pre_max = get_ood_score(ood_data_loader=iNt_loader, name="iNt", text_inputs=text_inputs, len_of_ID=L)
        sun_pre_max = get_ood_score(ood_data_loader=sun_loader, name="SUN", text_inputs=text_inputs, len_of_ID=L)
        place_pre_max = get_ood_score(ood_data_loader=place_loader, name="Places", text_inputs=text_inputs, len_of_ID=L)
        textures_pre_max = get_ood_score(ood_data_loader=textures_loader, name="Textures", text_inputs=text_inputs,
                                         len_of_ID=L)

        get_result(ID_score=ID_pre_max, OOD_score=int_pre_max, ood_name="iNt")
        get_result(ID_score=ID_pre_max, OOD_score=sun_pre_max, ood_name="SUN")
        get_result(ID_score=ID_pre_max, OOD_score=place_pre_max, ood_name="Places")
        get_result(ID_score=ID_pre_max, OOD_score=textures_pre_max, ood_name="Textures")

# %% [markdown]
# # Load Model

# %%
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model, transform = clip.load("ViT-B/16", device=device)
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Data Loader

# %%
textures = torchvision.datasets.ImageFolder(root=os.path.expanduser("dtd"), transform=transform)
textures_loader = torch.utils.data.DataLoader(textures, batch_size=256, shuffle=False, pin_memory=True, num_workers=10)

iNt = torchvision.datasets.ImageFolder(root=os.path.expanduser("iNaturalist"),
                                       transform=transform)
iNt_loader = torch.utils.data.DataLoader(iNt, batch_size=256, shuffle=False, pin_memory=True, num_workers=10)

place365 = torchvision.datasets.ImageFolder(root=os.path.expanduser("Places"),
                                            transform=transform)
place_loader = torch.utils.data.DataLoader(place365, batch_size=256, shuffle=False, pin_memory=True, num_workers=10)

sun = torchvision.datasets.ImageFolder(root=os.path.expanduser("SUN"), transform=transform)
sun_loader = torch.utils.data.DataLoader(sun, batch_size=256, shuffle=False, pin_memory=True, num_workers=10)

# %%
class IDDataset(torch.utils.data.Dataset):
    def __init__(self, root, is_train, preprocess):
        self.preprocess = preprocess
        self.root = root
        if is_train:
            self.dataset = datasets.ImageNet(root=root, transform=self.preprocess, split="train")
        else:
            self.dataset = datasets.ImageNet(root=root, transform=self.preprocess, split="val")
        self.dataset_class = [tup[0] for tup in self.dataset.classes]

    def get_classes(self):
        return self.dataset_class

    def __len__(self):
        return len(self.dataset)

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        return image, label

imagenet1k_dataset = IDDataset(root=os.path.expanduser("imagenet_1k"), is_train=False, preprocess=transform)
imagenet1k_dataloader = torch.utils.data.DataLoader(imagenet1k_dataset, batch_size=128, shuffle=False, pin_memory=True, num_workers=10)

imagenet1k_classes = [s.replace("_", " ") for s in imagenet1k_dataset.get_classes()]
print(imagenet1k_classes)
# Out:
# ['tench', 'goldfish', 'great white shark', 'tiger shark', 'hammerhead', 'electric ray', 'stingray', 'cock', 'hen', 'ostrich', 'brambling', 'goldfinch', 'house finch', 'junco', 'indigo bunting', 'robin', 'bulbul', 'jay', 'magpie', 'chickadee', 'water ouzel', 'kite', 'bald eagle', 'vulture', 'great grey owl', 'European fire salamander', 'common newt', 'eft', 'spotted salamander', 'axolotl', 'bullfrog', 'tree frog', 'tailed frog', 'loggerhead', 'leatherback turtle', 'mud turtle', 'terrapin', 'box turtle', 'banded gecko', 'common iguana', 'American chameleon', 'whiptail', 'agama', 'frilled lizard', 'alligator lizard', 'Gila monster', 'green lizard', 'African chameleon', 'Komodo dragon', 'African crocodile', 'American alligator', 'triceratops', 'thunder snake', 'ringneck snake', 'hognose snake', 'green snake', 'king snake', 'garter snake', 'water snake', 'vine snake', 'night snake', 'boa constrictor', 'rock python', 'Indian cobra', 'green mamba', 'sea snake', 'horned viper', 'diamondback', 'sidewinder', 'trilobite', 'harvestman', 'scorpion', 'black and gold garden spider', 'barn spider', 'garden spider', 'black widow', 'tarantula', 'wolf spider', 'tick', 'centipede', 'black grouse', 'ptarmigan', 'ruffed grouse', 'prairie chicken', 'peacock', 'quail', 'partridge', 'African grey', 'macaw', 'sulphur-crested cockatoo', 'lorikeet', 'coucal', 'bee eater', 'hornbill', 'hummingbird', 'jacamar', 'toucan', 'drake', 'red-breasted merganser', 'goose', 'black swan', 'tusker', 'echidna', 'platypus', 'wallaby', 'koala', 'wombat', 'jellyfish', 'sea anemone', 'brain coral', 'flatworm', 'nematode', 'conch', 'snail', 'slug', 'sea slug', 'chiton', 'chambered nautilus', 'Dungeness crab', 'rock crab', 'fiddler crab', 'king crab', 'American lobster', 'spiny lobster', 'crayfish', 'hermit crab', 'isopod', 'white stork', 'black stork', 'spoonbill', 'flamingo', 'little blue heron', 'American egret', 'bittern', 'crane', 'limpkin', 'European gallinule', 'American coot', 'bustard', 'ruddy turnstone', 'red-backed sandpiper', 'redshank', 'dowitcher', 'oystercatcher', 'pelican', 'king penguin', 'albatross', 'grey whale', 'killer whale', 'dugong', 'sea lion', 'Chihuahua', 'Japanese spaniel', 'Maltese dog', 'Pekinese', 'Shih-Tzu', 'Blenheim spaniel', 'papillon', 'toy terrier', 'Rhodesian ridgeback', 'Afghan hound', 'basset', 'beagle', 'bloodhound', 'bluetick', 'black-and-tan coonhound', 'Walker hound', 'English foxhound', 'redbone', 'borzoi', 'Irish wolfhound', 'Italian greyhound', 'whippet', 'Ibizan hound', 'Norwegian elkhound', 'otterhound', 'Saluki', 'Scottish deerhound', 'Weimaraner', 'Staffordshire bullterrier', 'American Staffordshire terrier', 'Bedlington terrier', 'Border terrier', 'Kerry blue terrier', 'Irish terrier', 'Norfolk terrier', 'Norwich terrier', 'Yorkshire terrier', 'wire-haired fox terrier', 'Lakeland terrier', 'Sealyham terrier', 'Airedale', 'cairn', 'Australian terrier', 'Dandie Dinmont', 'Boston bull', 'miniature schnauzer', 'giant schnauzer', 'standard schnauzer', 'Scotch terrier', 'Tibetan terrier', 'silky terrier', 'soft-coated wheaten terrier', 'West Highland white terrier', 'Lhasa', 'flat-coated retriever', 'curly-coated retriever', 'golden retriever', 'Labrador retriever', 'Chesapeake Bay retriever', 'German short-haired pointer', 'vizsla', 'English setter', 'Irish setter', 'Gordon setter', 'Brittany spaniel', 'clumber', 'English springer', 'Welsh springer spaniel', 'cocker spaniel', 'Sussex spaniel', 'Irish water spaniel', 'kuvasz', 'schipperke', 'groenendael', 'malinois', 'briard', 'kelpie', 'komondor', 'Old English sheepdog', 'Shetland sheepdog', 'collie', 'Border collie', 'Bouvier des Flandres', 'Rottweiler', 'German shepherd', 'Doberman', 'miniature pinscher', 'Greater Swiss Mountain dog', 'Bernese mountain dog', 'Appenzeller', 'EntleBucher', 'boxer', 'bull mastiff', 'Tibetan mastiff', 'French bulldog', 'Great Dane', 'Saint Bernard', 'Eskimo dog', 'malamute', 'Siberian husky', 'dalmatian', 'affenpinscher', 'basenji', 'pug', 'Leonbe ...

# %% [markdown]
# # Test

# %%
Agent = "a photo of a thing that we can see in nature."
test_in_ood_datasets(ID_dataloader=imagenet1k_dataloader, classes_list=imagenet1k_classes, ID_name="ImageNet-1k", Agent=Agent)
# Out:
# text input shape torch.Size([2000, 77])
# ID test dataset has finished 0.00%
# ID test dataset has finished 0.26%
# ID test dataset has finished 0.51%
# ID test dataset has finished 0.77%
# ID test dataset has finished 1.02%
# ID test dataset has finished 1.28%
# ID test dataset has finished 1.53%
# ID test dataset has finished 1.79%
# ID test dataset has finished 2.05%
# ID test dataset has finished 2.30%
# ID test dataset has finished 2.56%
# ID test dataset has finished 2.81%
# ID test dataset has finished 3.07%
# ID test dataset has finished 3.32%
# ID test dataset has finished 3.58%
# ID test dataset has finished 3.84%
# ID test dataset has finished 4.09%
# ID test dataset has finished 4.35%
# ID test dataset has finished 4.60%
# ID test dataset has finished 4.86%
# ID test dataset has finished 5.12%
# ID test dataset has finished 5.37%
# ID test dataset has finished 5.63%
# ID test dataset has finished 5.88%
# ID test dataset has finished 6.14%
# ID test dataset has finished 6.39%
# ID test dataset has finished 6.65%
# ID test dataset has finished 6.91%
# ID test dataset has finished 7.16%
# ID test dataset has finished 7.42%
# ID test dataset has finished 7.67%
# ID test dataset has finished 7.93%
# ID test dataset has finished 8.18%
# ID test dataset has finished 8.44%
# ID test dataset has finished 8.70%
# ID test dataset has finished 8.95%
# ID test dataset has finished 9.21%
# ID test dataset has finished 9.46%
# ID test dataset has finished 9.72%
# ID test dataset has finished 9.97%
# ID test dataset has finished 10.23%
# ID test dataset has finished 10.49%
# ID test dataset has finished 10.74%
# ID test dataset has finished 11.00%
# ID test dataset has finished 11.25%
# ID test dataset has finished 11.51%
# ID test dataset has finished 11.76%
# ID test dataset has finished 12.02%
# ID test dataset has finished 12.28%
# ID test dataset has finished 12.53%
# ID test dataset has finished 12.79%
# ID test dataset has finished 13.04%
# ID test dataset has finished 13.30%
# ID test dataset has finished 13.55%
# ID test dataset has finished 13.81%
# ID test dataset has finished 14.07%
# ID test dataset has finished 14.32%
# ID test dataset has finished 14.58%
# ID test dataset has finished 14.83%
# ID test dataset has finished 15.09%
# ID test dataset has finished 15.35%
# ID test dataset has finished 15.60%
# ID test dataset has finished 15.86%
# ID test dataset has finished 16.11%
# ID test dataset has finished 16.37%
# ID test dataset has finished 16.62%
# ID test dataset has finished 16.88%
# ID test dataset has finished 17.14%
# ID test dataset has finished 17.39%
# ID test dataset has finished 17.65%
# ID test dataset has finished 17.90%
# ID test dataset has finished 18.16%
# ID test dataset has finished 18.41%
# ID test dataset has finished 18.67%
# ID test dataset has finished 18.93%
# ID test dataset has finished 19.18%
# ID test dataset has finished 19.44%
# ID test dataset has finished 19.69%
# ID test dataset has finished 19.95%
# ID test dataset has finished 20.20%
# ID test dataset has finished 20.46%
# ID test dataset has finished 20.72%
# ID test dataset has finished 20.97%
# ID test dataset has finished 21.23%
# ID test dataset has finished 21.48%
# ID test dataset has finished 21.74%
# ID test dataset has finished 21.99%
# ID test dataset has finished 22.25%
# ID test dataset has finished 22.51%
# ID test dataset has finished 22.76%
# ID test dataset has finished 23.02%
# ID test dataset has finished 23.27%
# ID test dataset has finished 23.53%
# ID test dataset has finished 23.79%
# ID test dataset has finished 24.04%
# ID test dataset has finished 24.30%
# ID test dataset has finished 24.55%
# ID test dataset has finished 24.81%
# ID test dataset has finished 25.06%
# ID test dataset has finished 25.32%
# ID test dataset has finished 25.58%
# ID test dataset has finished 25.83%
# ID test dataset has finished 26.09%
# ID test dataset has finished 26.34%
# ID test dataset has finished 26.60%
# ID test dataset has finished 26.85%
# ID test dataset has finished 27.11%
# ID test dataset has finished 27.37%
# ID test dataset has finished 27.62%
# ID test dataset has finished 27.88%
# ID test dataset has finished 28.13%
# ID test dataset has finished 28.39%
# ID test dataset has finished 28.64%
# ID test dataset has finished 28.90%
# ID test dataset has finished 29.16%
# ID test dataset has finished 29.41%
# ID test dataset has finished 29.67%
# ID test dataset has finished 29.92%
# ID test dataset has finished 30.18%
# ID test dataset has finished 30.43%
# ID test dataset has finished 30.69%
# ID test dataset has finished 30.95%
# ID test dataset has finished 31.20%
# ID test dataset has finished 31.46%
# ID test dataset has finished 31.71%
# ID test dataset has finished 31.97%
# ID test dataset has finished 32.23%
# ID test dataset has finished 32.48%
# ID test dataset has finished 32.74%
# ID test dataset has finished 32.99%
# ID test dataset has finished 33.25%
# ID test dataset has finished 33.50%
# ID test dataset has finished 33.76%
# ID test dataset has finished 34.02%
# ID test dataset has finished 34.27%
# ID test dataset has finished 34.53%
# ID test dataset has finished 34.78%
# ID test dataset has finished 35.04%
# ID test dataset has finished 35.29%
# ID test dataset has finished 35.55%
# ID test dataset has finished 35.81%
# ID test dataset has finished 36.06%
# ID test dataset has finished 36.32%
# ID test dataset has finished 36.57%
# ID test dataset has finished 36.83%
# ID test dataset has finished 37.08%
# ID test dataset has finished 37.34%
# ID test dataset has finished 37.60%
# ID test dataset has finished 37.85%
# ID test dataset has finished 38.11%
# ID test dataset has finished 38.36%
# ID test dataset has finished 38.62%
# ID test dataset has finished 38.87%
# ID test dataset has finished 39.13%
# ID test dataset has finished 39.39%
# ID test dataset has finished 39.64%
# ID test dataset has finished 39.90%
# ID test dataset has finished 40.15%
# ID test dataset has finished 40.41%
# ID test dataset has finished 40.66%
# ID test dataset has finished 40.92%
# ID test dataset has finished 41.18%
# ID test dataset has finished 41.43%
# ID test dataset has finished 41.69%
# ID test dataset has finished 41.94%
# ID test dataset has finished 42.20%
# ID test dataset has finished 42.46%
# ID test dataset has finished 42.71%
# ID test dataset has finished 42.97%
# ID test dataset has finished 43.22%
# ID test dataset has finished 43.48%
# ID test dataset has finished 43.73%
# ID test dataset has finished 43.99%
# ID test dataset has finished 44.25%
# ID test dataset has finished 44.50%
# ID test dataset has finished 44.76%
# ID test dataset has finished 45.01%
# ID test dataset has finished 45.27%
# ID test dataset has finished 45.52%
# ID test dataset has finished 45.78%
# ID test dataset has finished 46.04%
# ID test dataset has finished 46.29%
# ID test dataset has finished 46.55%
# ID test dataset has finished 46.80%
# ID test dataset has finished 47.06%
# ID test dataset has finished 47.31%
# ID test dataset has finished 47.57%
# ID test dataset has finished 47.83%
# ID test dataset has finished 48.08%
# ID test dataset has finished 48.34%
# ID test dataset has finished 48.59%
# ID test dataset has finished 48.85%
# ID test dataset has finished 49.10%
# ID test dataset has finished 49.36%
# ID test dataset has finished 49.62%
# ID test dataset has finished 49.87%
# ID test dataset has finished 50.13%
# ID test dataset has finished 50.38%
# ID test dataset has finished 50.64%
# ID test dataset has finished 50.90%
# ID test dataset has finished 51.15%
# ID test dataset has finished 51.41%
# ID test dataset has finished 51.66%
# ID test dataset has finished 51.92%
# ID test dataset has finished 52.17%
# ID test dataset has finished 52.43%
# ID test dataset has finished 52.69%
# ID test dataset has finished 52.94%
# ID test dataset has finished 53.20%
# ID test dataset has finished 53.45%
# ID test dataset has finished 53.71%
# ID test dataset has finished 53.96%
# ID test dataset has finished 54.22%
# ID test dataset has finished 54.48%
# ID test dataset has finished 54.73%
# ID test dataset has finished 54.99%
# ID test dataset has finished 55.24%
# ID test dataset has finished 55.50%
# ID test dataset has finished 55.75%
# ID test dataset has finished 56.01%
# ID test dataset has finished 56.27%
# ID test dataset has finished 56.52%
# ID test dataset has finished 56.78%
# ID test dataset has finished 57.03%
# ID test dataset has finished 57.29%
# ID test dataset has finished 57.54%
# ID test dataset has finished 57.80%
# ID test dataset has finished 58.06%
# ID test dataset has finished 58.31%
# ID test dataset has finished 58.57%
# ID test dataset has finished 58.82%
# ID test dataset has finished 59.08%
# ID test dataset has finished 59.34%
# ID test dataset has finished 59.59%
# ID test dataset has finished 59.85%
# ID test dataset has finished 60.10%
# ID test dataset has finished 60.36%
# ID test dataset has finished 60.61%
# ID test dataset has finished 60.87%
# ID test dataset has finished 61.13%
# ID test dataset has finished 61.38%
# ID test dataset has finished 61.64%
# ID test dataset has finished 61.89%
# ID test dataset has finished 62.15%
# ID test dataset has finished 62.40%
# ID test dataset has finished 62.66%
# ID test dataset has finished 62.92%
# ID test dataset has finished 63.17%
# ID test dataset has finished 63.43%
# ID test dataset has finished 63.68%
# ID test dataset has finished 63.94%
# ID test dataset has finished 64.19%
# ID test dataset has finished 64.45%
# ID test dataset has finished 64.71%
# ID test dataset has finished 64.96%
# ID test dataset has finished 65.22%
# ID test dataset has finished 65.47%
# ID test dataset has finished 65.73%
# ID test dataset has finished 65.98%
# ID test dataset has finished 66.24%
# ID test dataset has finished 66.50%
# ID test dataset has finished 66.75%
# ID test dataset has finished 67.01%
# ID test dataset has finished 67.26%
# ID test dataset has finished 67.52%
# ID test dataset has finished 67.77%
# ID test dataset has finished 68.03%
# ID test dataset has finished 68.29%
# ID test dataset has finished 68.54%
# ID test dataset has finished 68.80%
# ID test dataset has finished 69.05%
# ID test dataset has finished 69.31%
# ID test dataset has finished 69.57%
# ID test dataset has finished 69.82%
# ID test dataset has finished 70.08%
# ID test dataset has finished 70.33%
# ID test dataset has finished 70.59%
# ID test dataset has finished 70.84%
# ID test dataset has finished 71.10%
# ID test dataset has finished 71.36%
# ID test dataset has finished 71.61%
# ID test dataset has finished 71.87%
# ID test dataset has finished 72.12%
# ID test dataset has finished 72.38%
# ID test dataset has finished 72.63%
# ID test dataset has finished 72.89%
# ID test dataset has finished 73.15%
# ID test dataset has finished 73.40%
# ID test dataset has finished 73.66%
# ID test dataset has finished 73.91%
# ID test dataset has finished 74.17%
# ID test dataset has finished 74.42%
# ID test dataset has finished 74.68%
# ID test dataset has finished 74.94%
# ID test dataset has finished 75.19%
# ID test dataset has finished 75.45%
# ID test dataset has finished 75.70%
# ID test dataset has finished 75.96%
# ID test dataset has finished 76.21%
# ID test dataset has finished 76.47%
# ID test dataset has finished 76.73%
# ID test dataset has finished 76.98%
# ID test dataset has finished 77.24%
# ID test dataset has finished 77.49%
# ID test dataset has finished 77.75%
# ID test dataset has finished 78.01%
# ID test dataset has finished 78.26%
# ID test dataset has finished 78.52%
# ID test dataset has finished 78.77%
# ID test dataset has finished 79.03%
# ID test dataset has finished 79.28%
# ID test dataset has finished 79.54%
# ID test dataset has finished 79.80%
# ID test dataset has finished 80.05%
# ID test dataset has finished 80.31%
# ID test dataset has finished 80.56%
# ID test dataset has finished 80.82%
# ID test dataset has finished 81.07%
# ID test dataset has finished 81.33%
# ID test dataset has finished 81.59%
# ID test dataset has finished 81.84%
# ID test dataset has finished 82.10%
# ID test dataset has finished 82.35%
# ID test dataset has finished 82.61%
# ID test dataset has finished 82.86%
# ID test dataset has finished 83.12%
# ID test dataset has finished 83.38%
# ID test dataset has finished 83.63%
# ID test dataset has finished 83.89%
# ID test dataset has finished 84.14%
# ID test dataset has finished 84.40%
# ID test dataset has finished 84.65%
# ID test dataset has finished 84.91%
# ID test dataset has finished 85.17%
# ID test dataset has finished 85.42%
# ID test dataset has finished 85.68%
# ID test dataset has finished 85.93%
# ID test dataset has finished 86.19%
# ID test dataset has finished 86.45%
# ID test dataset has finished 86.70%
# ID test dataset has finished 86.96%
# ID test dataset has finished 87.21%
# ID test dataset has finished 87.47%
# ID test dataset has finished 87.72%
# ID test dataset has finished 87.98%
# ID test dataset has finished 88.24%
# ID test dataset has finished 88.49%
# ID test dataset has finished 88.75%
# ID test dataset has finished 89.00%
# ID test dataset has finished 89.26%
# ID test dataset has finished 89.51%
# ID test dataset has finished 89.77%
# ID test dataset has finished 90.03%
# ID test dataset has finished 90.28%
# ID test dataset has finished 90.54%
# ID test dataset has finished 90.79%
# ID test dataset has finished 91.05%
# ID test dataset has finished 91.30%
# ID test dataset has finished 91.56%
# ID test dataset has finished 91.82%
# ID test dataset has finished 92.07%
# ID test dataset has finished 92.33%
# ID test dataset has finished 92.58%
# ID test dataset has finished 92.84%
# ID test dataset has finished 93.09%
# ID test dataset has finished 93.35%
# ID test dataset has finished 93.61%
# ID test dataset has finished 93.86%
# ID test dataset has finished 94.12%
# ID test dataset has finished 94.37%
# ID test dataset has finished 94.63%
# ID test dataset has finished 94.88%
# ID test dataset has finished 95.14%
# ID test dataset has finished 95.40%
# ID test dataset has finished 95.65%
# ID test dataset has finished 95.91%
# ID test dataset has finished 96.16%
# ID test dataset has finished 96.42%
# ID test dataset has finished 96.68%
# ID test dataset has finished 96.93%
# ID test dataset has finished 97.19%
# ID test dataset has finished 97.44%
# ID test dataset has finished 97.70%
# ID test dataset has finished 97.95%
# ID test dataset has finished 98.21%
# ID test dataset has finished 98.47%
# ID test dataset has finished 98.72%
# ID test dataset has finished 98.98%
# ID test dataset has finished 99.23%
# ID test dataset has finished 99.49%
# ID test dataset has finished 99.74%
# iNt has finished 0%
# iNt has finished 2%
# iNt has finished 5%
# iNt has finished 8%
# iNt has finished 10%
# iNt has finished 12%
# iNt has finished 15%
# iNt has finished 18%
# iNt has finished 20%
# iNt has finished 22%
# iNt has finished 25%
# iNt has finished 28%
# iNt has finished 30%
# iNt has finished 32%
# iNt has finished 35%
# iNt has finished 38%
# iNt has finished 40%
# iNt has finished 42%
# iNt has finished 45%
# iNt has finished 48%
# iNt has finished 50%
# iNt has finished 52%
# iNt has finished 55%
# iNt has finished 57%
# iNt has finished 60%
# iNt has finished 62%
# iNt has finished 65%
# iNt has finished 68%
# iNt has finished 70%
# iNt has finished 72%
# iNt has finished 75%
# iNt has finished 78%
# iNt has finished 80%
# iNt has finished 82%
# iNt has finished 85%
# iNt has finished 88%
# iNt has finished 90%
# iNt has finished 92%
# iNt has finished 95%
# iNt has finished 98%
# SUN has finished 0%
# SUN has finished 2%
# SUN has finished 5%
# SUN has finished 8%
# SUN has finished 10%
# SUN has finished 12%
# SUN has finished 15%
# SUN has finished 18%
# SUN has finished 20%
# SUN has finished 22%
# SUN has finished 25%
# SUN has finished 28%
# SUN has finished 30%
# SUN has finished 32%
# SUN has finished 35%
# SUN has finished 38%
# SUN has finished 40%
# SUN has finished 42%
# SUN has finished 45%
# SUN has finished 48%
# SUN has finished 50%
# SUN has finished 52%
# SUN has finished 55%
# SUN has finished 57%
# SUN has finished 60%
# SUN has finished 62%
# SUN has finished 65%
# SUN has finished 68%
# SUN has finished 70%
# SUN has finished 72%
# SUN has finished 75%
# SUN has finished 78%
# SUN has finished 80%
# SUN has finished 82%
# SUN has finished 85%
# SUN has finished 88%
# SUN has finished 90%
# SUN has finished 92%
# SUN has finished 95%
# SUN has finished 98%
# Places has finished 0%
# Places has finished 2%
# Places has finished 5%
# Places has finished 8%
# Places has finished 10%
# Places has finished 12%
# Places has finished 15%
# Places has finished 18%
# Places has finished 20%
# Places has finished 22%
# Places has finished 25%
# Places has finished 28%
# Places has finished 30%
# Places has finished 32%
# Places has finished 35%
# Places has finished 38%
# Places has finished 40%
# Places has finished 42%
# Places has finished 45%
# Places has finished 48%
# Places has finished 50%
# Places has finished 52%
# Places has finished 55%
# Places has finished 57%
# Places has finished 60%
# Places has finished 62%
# Places has finished 65%
# Places has finished 68%
# Places has finished 70%
# Places has finished 72%
# Places has finished 75%
# Places has finished 78%
# Places has finished 80%
# Places has finished 82%
# Places has finished 85%
# Places has finished 88%
# Places has finished 90%
# Places has finished 92%
# Places has finished 95%
# Places has finished 98%
# Textures has finished 0%
# Textures has finished 4%
# Textures has finished 9%
# Textures has finished 13%
# Textures has finished 17%
# Textures has finished 22%
# Textures has finished 26%
# Textures has finished 30%
# Textures has finished 35%
# Textures has finished 39%
# Textures has finished 43%
# Textures has finished 48%
# Textures has finished 52%
# Textures has finished 57%
# Textures has finished 61%
# Textures has finished 65%
# Textures has finished 70%
# Textures has finished 74%
# Textures has finished 78%
# Textures has finished 83%
# Textures has finished 87%
# Textures has finished 91%
# Textures has finished 96%
# OOD is iNt, The AUC score is:[0.9544809399999999], The FPR95 score is:[0.2384]
# OOD is SUN, The AUC score is:[0.933916178], The FPR95 score is:[0.3051]
# OOD is Places, The AUC score is:[0.931792568], The FPR95 score is:[0.2986]
# OOD is Textures, The AUC score is:[0.8847928156028368], The FPR95 score is:[0.4735815602836879]
